# %% [markdown]
# # Monte Carlo Class Follow Up
#
# Grzegorz Malisz
#
# Student Number: 4852370
#
# [GitHub Repository](https://github.com/grzgm/deth)

# %%
import random
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Code

# %%
def walking():
    number_of_walks = 10000

    for walk_length in range(1, 10):
        # visited_intersection_count = [[0 for _ in range(walk_length * 2 + 1)] for __ in range(walk_length * 2 + 1)]
        visited_intersection_count = np.zeros((walk_length * 2 + 1, walk_length * 2 + 1))
        for i in range(number_of_walks):
            x, y = walk_length, walk_length
            for j in range(walk_length):
                (dx, dy) = random.choice([(0, 1), (0, -1), (1, 0), (-1, 0)])
                x += dx
                y += dy
                visited_intersection_count[y][x] += 1

        for y in range(walk_length * 2 + 1):
            for x in range(walk_length * 2 + 1):
                visited_intersection_count[y][x] /= number_of_walks * walk_length

        # Reverse the order of rows (swap values on the y-axis) for more clear graph
        visited_intersection_count = visited_intersection_count[::-1, :]

        extent = [-walk_length - 0.5, walk_length + 0.5, -walk_length - 0.5, walk_length + 0.5]
        plt.imshow(visited_intersection_count, extent=extent)
        plt.colorbar()
        plt.title("Probability of visiting intersection Heat Map")
        plt.xlabel("X coordinates of grid")
        plt.ylabel("Y coordinates of grid")
        plt.show()

# %% [markdown]
# ## Assignment 1
#
# Agent performs random walks from length of 1 to 10 for 10000. For every walk distance the 2d array `visited_intersection_count` is initialised with the dimensions of `walk_length * 2 + 1` for x and y, just in case the walk is only in one direction. If the agent visits intersection value in the array with the corresponding coordinates is incremented.
#
# For the heatmap the values in the array are divided by the `number_of_walks * walk_length`, as this is all the 'steps' that agent makes for the all tries with the walk length. This allows to get the probability of ending in the certain state. Sum of all the probabilities for every intersection, possible to be accessed by agent is 1.
#
# I believe that I am generation enough simulations, as every time when I run the code it gives practically identical results

# %%
walking()
